# %%
import numpy as np
import pandas as pd
s1 = pd.Series([0,1], index=['a','b'])
display(s1)
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
display(s2)
s3 = pd.Series([5, 6], index=['f', 'g'])
display(s3)
# Out:
# a    0
# b    1
# dtype: int64
# c    2
# d    3
# e    4
# dtype: int64
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s2, s3])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s2, s3],axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
df1 = pd.DataFrame(np.arange(6).reshape(3, 2),
                   index=['a', 'b', 'c'],
                   columns=['one','two'])
display(df1)
df2 = pd.DataFrame(np.arange(4).reshape(2, 2),
                   index=['a', 'c'],
                   columns=['three','four'])
display(df2)
# Out:
#    one  two
# a    0    1
# b    2    3
# c    4    5
#    three  four
# a      0     1
# c      2     3

# %%
pd.concat([df1, df2],axis=1)
# Out:
#           a         b         c         d         b         d         a
# 0  0.515457 -0.331121 -0.734955  0.124855 -0.485923 -0.852031  0.453872
# 1 -1.803809  1.017067 -0.108664  0.186184  1.469612  0.638219  0.755160
# 2 -1.067303 -1.271416  1.967985  0.356193       NaN       NaN       NaN

# %%
pd.concat([df1, df2],axis=1,keys=['台北','台南'])
# Out:
#    台北        台南
#   one two three four
# a   0   1   0.0  1.0
# b   2   3   NaN  NaN
# c   4   5   2.0  3.0

# %%
df1 = pd.DataFrame(np.random.randn(3, 4), columns=['a', 'b', 'c', 'd'])
display(df1)
df2 = pd.DataFrame(np.random.randn(2, 3), columns=['b', 'd', 'a'])
display(df2)

pd.concat([df1,df2])
# Out:
#           a         b         c         d
# 0  0.515457 -0.331121 -0.734955  0.124855
# 1 -1.803809  1.017067 -0.108664  0.186184
# 2 -1.067303 -1.271416  1.967985  0.356193
#           b         d         a
# 0 -0.485923 -0.852031  0.453872
# 1  1.469612  0.638219  0.755160
#           a         b         c         d
# 0  0.515457 -0.331121 -0.734955  0.124855
# 1 -1.803809  1.017067 -0.108664  0.186184
# 2 -1.067303 -1.271416  1.967985  0.356193
# 0  0.453872 -0.485923       NaN -0.852031
# 1  0.755160  1.469612       NaN  0.638219

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#           a         b         c         d
# 0  0.515457 -0.331121 -0.734955  0.124855
# 1 -1.803809  1.017067 -0.108664  0.186184
# 2 -1.067303 -1.271416  1.967985  0.356193
# 3  0.453872 -0.485923       NaN -0.852031
# 4  0.755160  1.469612       NaN  0.638219

# %%
import yfinance as yf
data = yf.download("2330.TW", start="2022-01-01",end="2022-12-31")
tw2330 = data[['Adj Close']]
tw2330.columns = ['台積電']
tw2330
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    台積電
# Date
# 2022-01-03  604.633057
# 2022-01-04  628.588379
# 2022-01-05  622.839172
# 2022-01-06  617.089905
# 2022-01-07  607.507812
# ...                ...
# 2022-12-26  447.084564
# 2022-12-27  447.574249
# 2022-12-28  441.697998
# 2022-12-29  436.801147
# 2022-12-30  439.249573
#
# [246 rows x 1 columns]

# %%
data = yf.download("2303.TW", start="2022-01-01",end="2022-12-31")
tw2303 = data[['Adj Close']]
tw2303.columns = ['聯電']
tw2303
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    聯電
# Date
# 2022-01-03  55.519875
# 2022-01-04  55.169590
# 2022-01-05  55.257156
# 2022-01-06  54.906876
# 2022-01-07  54.819305
# ...               ...
# 2022-12-26  39.069618
# 2022-12-27  39.022995
# 2022-12-28  38.043922
# 2022-12-29  37.997299
# 2022-12-30  37.950680
#
# [246 rows x 1 columns]

# %%
pd.concat([tw2330,tw2303],axis=1)
# Out:
#                    台積電         聯電
# Date
# 2022-01-03  604.633057  55.519875
# 2022-01-04  628.588379  55.169590
# 2022-01-05  622.839172  55.257156
# 2022-01-06  617.089905  54.906876
# 2022-01-07  607.507812  54.819305
# ...                ...        ...
# 2022-12-26  447.084564  39.069618
# 2022-12-27  447.574249  39.022995
# 2022-12-28  441.697998  38.043922
# 2022-12-29  436.801147  37.997299
# 2022-12-30  439.249573  37.950680
#
# [246 rows x 2 columns]
