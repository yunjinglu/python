# %%
import pandas as pd
data = {"字串":["台北", "台中"],
        "整數":[1000, 3000],
        "浮點數":[3.258, 7.396]}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style.format(precision=2,thousands=',',decimal='.').relabel_index(['列一','列二'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_98f4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98f4c_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_98f4c_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_98f4c_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98f4c_level0_row0" class="row_heading level0 row0" >列一</th>
#       <td id="T_98f4c_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_98f4c_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_98f4c_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_98f4c_level0_row1" class="row_heading level0 row1" >列二</th>
#       <td id="T_98f4c_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_98f4c_row1_col1" class="data row1 col1" >3,000</td>
# ...

# %%
#視覺美化資料表
#pip install jinja2
df.style.\
format(precision=2,thousands=',',decimal='.')\
.relabel_index(['列一','列二'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_3b24a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b24a_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_3b24a_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_3b24a_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b24a_level0_row0" class="row_heading level0 row0" >列一</th>
#       <td id="T_3b24a_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_3b24a_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_3b24a_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_3b24a_level0_row1" class="row_heading level0 row1" >列二</th>
#       <td id="T_3b24a_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_3b24a_row1_col1" class="data row1 col1" >3,000</td>
# ...

# %%
import numpy as np
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-01",periods=10),
                  columns=["台北","台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  3.133564  3.788720
# 2023-09-02  4.966850  0.912434
# 2023-09-03  1.524785  4.569069
# 2023-09-04  0.541712  3.915800
# 2023-09-05  2.355688  0.113316
# 2023-09-06  2.310239  2.344216
# 2023-09-07  4.276079  4.081311
# 2023-09-08  1.753359  2.383353
# 2023-09-09  1.066469  1.480220
# 2023-09-10  2.600500  3.108003

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮溼"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None) #漸層顏色
# Out:
# <style type="text/css">
# #T_b3731_row0_col0 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_b3731_row0_col1 {
#   background-color: #1887a0;
#   color: #f1f1f1;
# }
# #T_b3731_row1_col0 {
#   background-color: #014838;
#   color: #f1f1f1;
# }
# #T_b3731_row1_col1, #T_b3731_row3_col0, #T_b3731_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b3731_row2_col0 {
#   background-color: #ebe1f0;
#   color: #000000;
# }
# #T_b3731_row2_col1 {
#   background-color: #016654;
#   color: #f1f1f1;
# }
# #T_b3731_row3_col1 {
#   background-color: #0b8393;
#   color: #f1f1f1;
# }
# #T_b3731_row4_col0, #T_b3731_row5_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_b3731_row5_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_b3731_row6_col0 {
#   background-color: #01756f;
#   color: #f1f1f1;
# }
# #T_b3731_row6_col1 {
#   background-color: #027d81;
#   color: #f1f1f1;
# }
# #T_b3731_row7_col0 {
#   background-color: #ded9eb;
# ...

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style\
.hide(subset=[0, 2, 4],axis=0)\
.hide(subset=[1,3],axis=1) #列axis=0 行axis=1
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a920">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a920_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1a920_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1a920_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a920_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a920_row1_col0" class="data row1 col0" >-0.134071</td>
#       <td id="T_1a920_row1_col2" class="data row1 col2" >-0.215102</td>
#       <td id="T_1a920_row1_col4" class="data row1 col4" >-0.441494</td>
#     </tr>
#     <tr>
#       <th id="T_1a920_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a920_row3_col0" class="data row3 col0" >-2.555232</td>
#       <td id="T_1a920_row3_col2" class="data row3 col2" >1.245080</td>
# ...
