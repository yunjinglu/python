# %%
import requests

url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
r = requests.get(url)
if r.status_code == 200:
    print("下載成功")
# Out:
# 下載成功

# %%
all_json = r.json()
locations = all_json['cwbopendata']['dataset']['location']
weather_list = []
for item in locations:
    city_item = {}
    city_item['城市'] = item['locationName']
    city_item['啟始時間'] = item['weatherElement'][1]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime']
    city_item['最高溫度'] = float(item['weatherElement'][1]['time'][0]['parameter']['parameterName'])
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '臺北市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新北市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適'},
#  {'城市': '桃園市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適'},
#  {'城市': '臺中市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 30.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺南市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '高雄市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '基隆市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新竹縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '新竹市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '苗栗縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '彰化縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '南投縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '雲林縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '嘉義縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '嘉義市',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '屏東縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 25.0,
#   '感覺': '舒適'},
#  {'城市': '宜蘭縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 23.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '花蓮縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 29.0,
#   '最低溫度': 24.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '臺東縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '澎湖縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '金門縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'},
#  {'城市': '連江縣',
#   '啟始時間': '2023-09-14T18:00:00+08:00',
#   '結束時間': '2023-09-15T06:00:00+08:00',
#   '最高溫度': 27.0,
#   '最低溫度': 26.0,
#   '感覺': '舒適至悶熱'}]

# %%
import pandas as pd 
weather_df = pd.DataFrame(weather_list)
weather_df
# Out:
#      城市                       啟始時間                       結束時間  最高溫度  最低溫度  \
# 0   臺北市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 1   新北市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 2   桃園市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 3   臺中市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  30.0  26.0
# 4   臺南市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  26.0
# 5   高雄市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  26.0
# 6   基隆市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  25.0
# 7   新竹縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 8   新竹市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 9   苗栗縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 10  彰化縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 11  南投縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 12  雲林縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  24.0
# 13  嘉義縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  25.0
# 14  嘉義市  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  24.0
# 15  屏東縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  25.0
# 16  宜蘭縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  23.0
# 17  花蓮縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  29.0  24.0
# 18  臺東縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  24.0
# 19  澎湖縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  26.0
# 20  金門縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  28.0  26.0
# 21  連江縣  2023-09-14T18:00:00+08:00  2023-09-15T06:00:00+08:00  27.0  26.0
#
#        感覺
# 0   舒適至悶熱
# 1      舒適
# 2      舒適
# 3   舒適至悶熱
# 4   舒適至悶熱
# 5   舒適至悶熱
# 6   舒適至悶熱
# 7   舒適至悶熱
# 8   舒適至悶熱
# 9   舒適至悶熱
# 10  舒適至悶熱
# 11  舒適至悶熱
# 12     舒適
# 13  舒適至悶熱
# 14     舒適
# 15     舒適
# 16  舒適至悶熱
# 17  舒適至悶熱
# 18     舒適
# 19  舒適至悶熱
# 20  舒適至悶熱
# 21  舒適至悶熱
